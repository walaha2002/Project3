# %%
from sklearn.model_selection import cross_val_score
>>> from sklearn.ensemble import RandomForestClassifier
>>> from sklearn.ensemble import ExtraTreesClassifier
>>> from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %%
nurse_df = pd.read_csv('../Resources/mainPop.csv')
nurse_df.head()
# Out:
#    ID  Cum GPA  TEAS Count  MaxOfTestScore                  PrecEducDesc  \
# 0   1     2.84         1.0            76.0  High School/GED/Some College
# 1   2     3.14         1.0            74.7  High School/GED/Some College
# 2   3     2.58         NaN             NaN  High School/GED/Some College
# 3   4     3.45         NaN             NaN  High School/GED/Some College
# 4   5     3.22         1.0            75.3  High School/GED/Some College
#
#    failing grade count  DateStart    GradDate Test Delivery Date  \
# 0                    0   9/6/2016   4/20/2018         11/15/2018
# 1                    0  9/10/2018  12/21/2019           3/3/2020
# 2                    0        NaN    5/1/2009          3/29/2019
# 3                    0        NaN   4/21/2017          5/27/2017
# 4                    0  5/18/2015  12/16/2016          3/10/2017
#
#    Time to Test (days)  Completion Time (days) Grade     Qtr  Year
# 0               209.00                   591.0  Pass  2018-4  2018
# ...

# %%
X = nurse_df[["Cum GPA", "TEAS Count","MaxOfTestScore","failing grade count","Time to Test (days)","Completion Time (days)",
        "HighSchool", "Assoc","Bach","Masters"]]


nurse_df = nurse_df.drop(['PrecEducDesc', 'Grade'], axis=1)
nurse_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7e7d5e5b5cbb> in <module>
#       1 X = nurse_df[["Cum GPA", "TEAS Count","MaxOfTestScore","failing grade count","Time to Test (days)","Completion Time (days)",
# ----> 2         "HighSchool", "Assoc","Bach","Masters"]]
#       3
#       4
#       5 nurse_df = nurse_df.drop(['PrecEducDesc', 'Grade'], axis=1)
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
# ...
